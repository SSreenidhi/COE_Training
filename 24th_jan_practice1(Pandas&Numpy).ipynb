# %%
import pandas as pd

# %%
import numpy as np

# %%
cd
# Out:
# C:\Users\CVR

# %%
hd=pd.read_csv("C://Users//CVR//PycharmProjects//NIDHI-Training//swiggy.csv")
hd.head()
# Out:
#     ID         Area       City         Restaurant Price Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut   300         4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi   300         4.1
# 2  246    Jogupalya  Bangalore            Kim Lee   650         4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel   NaN         3.9
# 4  249  Indiranagar  Bangalore                Nh8   350         NaN
#
#    Total ratings                                          Food type  \
# 0          100.0          Biryani,Chinese,North Indian,South Indian
# 1          100.0                                   Mughlai,Lucknowi
# 2          100.0                                            Chinese
# 3          500.0               North Indian,Punjabi,Tandoor,Chinese
# 4           50.0  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address Delivery time Unnamed: 10  Unnamed: 11
# 0     5Th Block            59         NaN          NaN
# ...

# %%
print(hd.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   int64
#  1   Area           8679 non-null   object
#  2   City           8674 non-null   object
#  3   Restaurant     8678 non-null   object
#  4   Price          8680 non-null   object
#  5   Avg ratings    8680 non-null   object
#  6   Total ratings  8680 non-null   float64
#  7   Food type      8680 non-null   object
#  8   Address        8680 non-null   object
#  9   Delivery time  8680 non-null   object
#  10  Unnamed: 10    11 non-null     object
#  11  Unnamed: 11    3 non-null      float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 813.9+ KB
# None

# %%
print(hd.shape)
# Out:
# (8680, 10)

# %%
print(hd.columns)
# Out:
# Index(['ID', 'Area', 'City', 'Restaurant', 'Price', 'Avg ratings',
#        'Total ratings', 'Food type', 'Address', 'Delivery time'],
#       dtype='object')

# %%
hd.iloc[1:21,1:4]
# Out:
#                    Area       City  \
# 1           Koramangala  Bangalore
# 2             Jogupalya  Bangalore
# 3           Indiranagar  Bangalore
# 4           Indiranagar  Bangalore
# 5           Indiranagar  Bangalore
# 6           Indiranagar  Bangalore
# 7           Koramangala  Bangalore
# 8                Domlur  Bangalore
# 9           Koramangala  Bangalore
# 10          Koramangala  Bangalore
# 11           Cooke Town  Bangalore
# 12      Pulikeshi Nagar  Bangalore
# 13  Sivanchetti Gardens  Bangalore
# 14            Kodihalli  Bangalore
# 15          Koramangala  Bangalore
# 16               Domlur  Bangalore
# 17          Indiranagar  Bangalore
# 18            Jayanagar  Bangalore
# 19           Film Nagar  Hyderabad
# 20          Indiranagar  Bangalore
#
#                                       Restaurant
# 1                                  Tunday Kababi
# 2                                        Kim Lee
# 3                              New Punjabi Hotel
# ...

# %%
hd.isnull()
# Out:
#          ID   Area   City  Restaurant  Price  Avg ratings  Total ratings  \
# 0     False  False  False       False  False        False          False
# 1     False  False  False       False  False        False          False
# 2     False  False  False       False  False        False          False
# 3     False  False  False       False   True        False          False
# 4     False  False  False       False  False         True          False
# ...     ...    ...    ...         ...    ...          ...            ...
# 8675  False  False  False       False  False        False          False
# 8676  False  False  False       False  False        False          False
# 8677  False  False  False       False  False        False          False
# 8678  False  False  False       False  False        False          False
# 8679  False  False  False       False  False        False          False
#
#       Food type  Address  Delivery time  Unnamed: 10  Unnamed: 11
# ...

# %%
hd.isnull().sum()
# Out:
# ID                  0
# Area                2
# City                6
# Restaurant          3
# Price               4
# Avg ratings         4
# Total ratings       0
# Food type           0
# Address             4
# Delivery time      13
# Unnamed: 10      8669
# Unnamed: 11      8677
# dtype: int64

# %%
hd['Area'].unique()
# Out:
# array(['Koramangala', 'Jogupalya', 'Indiranagar', 'Domlur', 'Cooke Town',
#        'Pulikeshi Nagar', 'Sivanchetti Gardens', 'Kodihalli', 'Jayanagar',
#        'Film Nagar', 'Banashankari', 'Masab Tank', 'Banjara Hills',
#        'Andheri East', 'Powai', 'Punjagutta', 'Aundh', 'Baner',
#        'Powai Area', 'Ramgopalpet', 'Kalasiguda', 'Adarsh Nagar',
#        'Himayatnagar', 'Ashok Nagar', 'Commercial Street',
#        'Richmond Town', 'Vasanth Nagar', 'Bhowanipore', 'Ballygunge',
#        'Gariahat', 'Kalighat', 'Sion', 'Mumbai', 'Rajajinagar', 'Golpark',
#        'Shivajinagar', 'Koregaon Park', 'Deccan Gymkhana', 'Karkhana',
#        'Kothrud', 'Erandwane', 'Koti', 'Dilsukhnagar', 'Nagole',
#        'Chandrapuri Colony', 'Kothapet', 'Narayanguda', 'Fc Road',
#        'Park Street Area', 'Beniapukur', 'Bidhannagar', 'New Nallakunta',
#        'Adikmet', 'Amberpet', 'Karve Nagar', 'Agarkar Nagar', 'Mundhwa',
# ...

# %%
hd.describe()
# Out:
#                   ID        Price  Avg ratings  Total ratings  Delivery time
# count    8680.000000  8680.000000  8680.000000    8680.000000    8680.000000
# mean   244812.071429   348.444470     3.655104     156.634793      53.967051
# std    158671.617188   230.940074     0.647629     391.448014      14.292335
# min       211.000000     0.000000     2.000000      20.000000      20.000000
# 25%     72664.000000   200.000000     2.900000      50.000000      44.000000
# 50%    283442.000000   300.000000     3.900000      80.000000      53.000000
# 75%    393425.250000   400.000000     4.200000     100.000000      64.000000
# max    466928.000000  2500.000000     5.000000   10000.000000     109.000000

# %%
hd.rename(columns={'Area': 'Location'}, inplace=True)

# %%
hd.head()
# Out:
#     ID     Location       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %% [markdown]
# # statistical methods

# %%
swiggi_mean=hd['Delivery time'].mean()
swiggi_mean
# Out:
# 53.96705069124424

# %%
swiggi_mode=hd["Avg ratings"].mode()
swiggi_mode
# Out:
# 0    2.9
# Name: Avg ratings, dtype: float64

# %%
hd.to_numpy()
# Out:
# array([[211, 'Koramangala', 'Bangalore', ..., '59', nan, nan],
#        [221, 'Koramangala', 'Bangalore', ..., '56', nan, nan],
#        [246, 'Jogupalya', 'Bangalore', ..., '50', nan, nan],
#        ...,
#        [465872, 'Rohini', 'Delhi', ..., '58', nan, nan],
#        [465990, 'Rohini', 'Delhi', ..., '28', nan, nan],
#        [466488, 'Navrangpura', 'Ahmedabad', ..., '44', nan, nan]],
#       dtype=object)

# %%
hd.sort_values(by="City")
# Out:
#           ID           Area       City                       Restaurant Price  \
# 8679  466488    Navrangpura  Ahmedabad                     Sassy Street   250
# 5555  433083    Navrangpura  Ahmedabad               Punjab Paratha Hub   300
# 5533  432334      Vastrapur  Ahmedabad      Chula Matka Biryani Kitchen   400
# 5532  432310      Maninagar  Ahmedabad                   Fire On Wheels   400
# 5511  431712      Vastrapur  Ahmedabad  One Fine Dine The Cloud Kitchen   280
# ...      ...            ...        ...                              ...   ...
# 51      2840    Ashok Nagar        NaN                          Roomali  1000
# 52      2843    Ashok Nagar        NaN                      Tadka Singh   300
# 53      2914    Ashok Nagar        NaN                          Bheemas   550
# 54      2915  Vasanth Nagar        NaN                         Watson'S   450
# 83      3855  Koregaon Park        NaN                  Uncle'S Chinese   350
#
# ...
